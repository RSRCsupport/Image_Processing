# %% [markdown]
# ## Gdal initial test
# This is a first test to have gdal working for students. First things you need to do is to install anaconda and then open Jupiter Notebook.

# %%
import gdal

# %%
import os

# %% [markdown]
# Esto es para cerciorarme donde estoy en el dir

# %%
os.getcwd()
# Out:
# 'U:\\'

# %% [markdown]
# Aqui abrire una funcion a ver si funciona la vaina

# %%
import os

# %%
os.chdir('U:\\')
# Out:
# 'U:\\'

# %% [markdown]
# ls

# %%
filename='20170306_231010_0e30_3B_Analytic.tif'

# %% [markdown]
# - probably here I should introduce how to do gdal calc. this is for tomorrow

# %%
def convertimg(filename):
    cmd='gdal_translate -of HFA {} outimg.img'.format(filename)
    os.system(cmd)

# %%
convertimg(filename)

# %% [markdown]
# Done the outimg.img was created. Now I will show the .img image

# %%
image=gdal.Open('outimg.img')

# %%
image_gdal =image.GetRasterBand(2).ReadAsArray()
print (image_gdal.shape)
# Out:
# (4638, 9316)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Next step to plot the image

# %%
plt.imshow(image_gdal)#, cmap = "hot", interpolation='nearest', aspect='auto')
plt.colorbar()
plt.show()

# %%
os.chdir('U:\\')
